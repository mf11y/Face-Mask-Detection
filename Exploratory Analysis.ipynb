# %%
import glob
import random
import cv2
import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

# %%
w_mask_dir = './Data/train/with_mask/'
wo_mask_dir = './Data/train/without_mask/'

wo_mask_pics = [f for f in glob.glob('./Data/train/without_mask/*')]
w_mask_pics = [f for f in glob.glob('./Data/train/with_mask/*')]

# %%
for i in range(331, 339):
    plt.subplot(i)
    random_num = np.random.randint(0,len(wo_mask_pics))
    img = cv2.imread(wo_mask_pics[random_num])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.imshow(img)

# %%
for i in range(331, 339):
    plt.subplot(i)
    random_num = np.random.randint(0,len(w_mask_pics))
    img = cv2.imread(w_mask_pics[random_num])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.imshow(img)

# %%
init = load_img(w_mask_pics[0], color_mode='rgb')
init = img_to_array(init)
init = [init.ravel()]

full_mat = init

for x in w_mask_pics[1:]:
    img = load_img(x)
    img = img_to_array(img)
    img_ts = [img.ravel()]

    full_mat = np.concatenate((full_mat, img))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-80c88384070a> in <module>
#      10     img_ts = [img.ravel()]
#      11
# ---> 12     full_mat = np.concatenate((full_mat, img))
#      13
#      14
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 3 dimension(s)

# %%
w_mask_dir
# Out:
# './Data/train/with_mask/'
